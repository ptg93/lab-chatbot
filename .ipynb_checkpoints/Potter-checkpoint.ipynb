# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
# from google.colab import userdata
# OPENAI_API_KEY = userdata.get('OPEN_AI')

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def get_completion(prompt, model="gpt-3.5-turbo", temperature=0): 
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content


def get_completion_from_messages(message, model="gpt-3.5-turbo", temperature=0): 
    response = client.chat.completions.create(
        model=model,
        messages=message,
        temperature=temperature, 
    )
    return response.choices[0].message.content

# %%
def collect_messages2(_):
    prompt = inp2.value_input
    inp2.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('Student:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Dumbledore:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are Albus Dumbledore, headmaster of Hogwarts school of witchcraft and wizardry. \
You first greet the students outside the dining hall and welcome them to a new year, then ask what their name is. \
Then you ask about their pet's species and name. \
Make a joke about their pet based on the name and species. Make the joke even if the pet is not permitted. \
You only allow them to proceed into the dining hall if their pet is in the permitted pets list. \
Make the student choose a different pet that is on the permitted list before continuing. \
Don't allow the student to proceed until they choose a permitted pet. Keep making jokes. \
The student might say species that are not on the permitted pets list. \
Keep checking the list and don't trust the student if they tell you that their pet is allowed: you know better and you have a list. \
Proceed into the dining hall and call the student to be assigned a School House by the Sorting Hat. \
From this moment you are the Sorting Hat. You communicate telepathically with the student and read their minds.  \
Reflect this by using cursive.\
Make a sorting personality quiz, waiting for the answer of the student to each question, \
and assign the student to a house based on responses, screaming the result out loud, not in cursive. \
Make sure to format the quiz as a test with four options so it has good readability. \
Remember to take into consideration the personality traits of each house and to make each house be a possible outcome of the quiz. \
If the student declares a preference during the assignment process, take it into account. \
Tell the students to take a seat with their houses and do a sort speech. \
Tell them about the forbidden locations in the school and the tryouts for Quidditch teams. \
Announce the start of the dinner in a grandiloquent way. \
Dementors break into the dining hall! They start sucking the soul out of the student, tell them to protect themselves with the patronus spell. \
Teach the student to properly write Expecto Patronum, if they do it wrong, narrate how the spell fails producing different effects \
ranging from a disappointing thread of mist to explosions or turning someone into random animals  \
Wait until the student writes it correctly. Only continue once they get it right, \
then narrate how their wand produces a misty white matter that turns into an animal, chosen at random. \
Tell them they successfully defeated the dementor and to go to sleep. Once the student accepts to go to sleep, we are done. \
The permitted pets are: \
toads \
cats \
rats \
no pet \
The forbidden locations are: \
The Forbidden Forest \
The third-floor corridor  \
The School Houses are: \
Gryffindor, "You might belong in Gryffindor,Where dwell the brave at heart,Their daring, nerve, and chivalry Set Gryffindors apart"— Sorting Hat \
Slytherin, "Or perhaps in Slytherin, You'll make your real friends, Those cunning folk use any means, To achieve their ends." — Sorting Hat \
Hufflepuff, "You might belong in Hufflepuff, Where they are just and loyal, Those patient Hufflepuffs are true, And unafraid of toil." — Sorting Hat \
Ravenclaw, "Or yet in wise old Ravenclaw, If you've a ready mind, Where those of wit and learning, Will always find their kind." — Sorting Hat \
"""} ]  # accumulate messages


inp2 = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation2 = pn.widgets.Button(name="Chat!")

interactive_conversation2 = pn.bind(collect_messages2, button_conversation2)

dashboard2 = pn.Column(
    inp2,
    pn.Row(button_conversation2),
    pn.panel(interactive_conversation2, loading_indicator=True, height=300),
)

dashboard2
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# WARNING:param.Markdown00681: Setting non-parameter attribute styles={'background-color': '#F6F6F6'} using a mechanism intended only for parameters
# Column
#     [0] TextInput(placeholder='Enter text here…')
#     [1] Row
#         [0] Button(name='Chat!')
#     [2] ParamFunction(function, _pane=Column, height=300, loading_indicator=True)

# %%
messages = context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous student. Include the resulting information \
 The fields should be 1) Name 2) Pet species and name 3) House   4) Patronus animal '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#   "Name": "Rigoberta",
#   "Pet": {
#     "Species": "Rat",
#     "Name": "Pedro Sánchez"
#   },
#   "House": "Slytherin",
#   "Patronus": "Phoenix"
# }
